# %% [markdown]
# #**CENSUS IN INDIA DATA ANALYSIS**
#
#
# ---
#
#
#
# #About Dataset
#
# This dataset provides comprehensive demographic information for various districts in India. It includes data on population, growth rates, sex ratios, and literacy rates. The dataset offers insights into the socio-economic landscape of Indian districts, making it valuable for demographic analyses, regional studies, and decision-making processes.
#
#
# ---
#
#
#
# To know more: https://www.kaggle.com/datasets/shiivvvaam/indian-districts-population-data

# %% [markdown]
# #**Problem Statement**
#
#
# ---
#
#
# #What is India's position in terms of its sex-ratio and litracy rate? Additionally, identify the rationale behind conducting an analysis on this dataset. Finally, provide a summary of all key parameters associated with it?

# %% [markdown]
# #**Questions:**
# #1. What state had the highest litracy rate?
# #2. What Distrcit had the highest litracty rate?
# #3. What state had the highest sex-ratio?
# #4. What District had the highest sex-ratio?
#
#
# ---
#
#
# NOTE: **The given dataset is not the true data, it is based on the sample size of the census of india in 2011. This might lead us to the false analysis.**
#
#
#
#
# ---

# %% [markdown]
# Import all library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv("/content/drive/MyDrive/Mini project/Census of india(2011) data analysis/census2011.csv")

# %%
df
# Out:
#      Ranking                    District                        State  \
# 0          1                       Thane                  Maharashtra
# 1          2  North Twenty Four Parganas                  West Bengal
# 2          3                   Bangalore                    Karnataka
# 3          4                        Pune                  Maharashtra
# 4          5             Mumbai Suburban                  Maharashtra
# ..       ...                         ...                          ...
# 605      636                    Nicobars  Andaman and Nicobar Islands
# 606      637                 Upper Siang            Arunachal Pradesh
# 607      638             Lahul and Spiti             Himachal Pradesh
# 608      639                       Anjaw            Arunachal Pradesh
# 609      640               Dibang Valley            Arunachal Pradesh
#
#      Population    Growth  Sex-Ratio  Literacy
# 0    11,060,148   36.01 %        886     84.53
# ...

# %%
df.columns
# Out:
# Index(['Ranking', 'District', 'State', 'Population', 'Growth', 'Sex-Ratio',
#        'Literacy'],
#       dtype='object')

# %%
df.shape
# Out:
# (610, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ranking     610 non-null    int64
#  1   District    610 non-null    object
#  2   State       610 non-null    object
#  3   Population  610 non-null    object
#  4   Growth      610 non-null    object
#  5   Sex-Ratio   610 non-null    int64
#  6   Literacy    610 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 33.5+ KB

# %%
df.columns.isnull().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           Ranking    Sex-Ratio    Literacy
# count  610.000000   610.000000  610.000000
# mean   329.598361   944.914754   72.344344
# std    184.656903    61.247694   10.540881
# min      1.000000   534.000000   36.100000
# 25%    183.250000   905.000000   65.255000
# 50%    335.500000   948.000000   72.150000
# 75%    487.750000   982.000000   79.987500
# max    640.000000  1184.000000   97.910000

# %% [markdown]
# #finding outlier

# %%
sns.boxplot(df['Sex-Ratio'])
plt.show()

# %%
sns.boxplot(df['Literacy'])
plt.show()

# %% [markdown]
# #Q1. Which state has the higest litracy rate in india in 2011?

# %%
literacy=df.groupby('State')['Literacy'].max().sort_values(ascending=False).head(6)
print(literacy)
# Out:
# State
# Mizoram        97.91
# Puducherry     97.87
# Kerala         97.21
# Lakshadweep    91.85
# Tamil Nadu     91.75
# Nagaland       91.62
# Name: Literacy, dtype: float64

# %%
literacy_df=literacy.reset_index()
fig=px.bar(literacy_df,x='State',y='Literacy',color_discrete_sequence=['blue'], text='Literacy')
fig.update_layout(title_x=0.5)
fig.update_layout(title_text="Literacy rate of states in india in 2011")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Mizoram had the highest litracy rate in 2011 = **97.91%**

# %% [markdown]
# #Q2. Which district has the higest litracy rate in india in 2011?

# %%
df.head(6)
# Out:
#    Ranking                    District        State  Population   Growth  \
# 0        1                       Thane  Maharashtra  11,060,148  36.01 %
# 1        2  North Twenty Four Parganas  West Bengal  10,009,781  12.04 %
# 2        3                   Bangalore    Karnataka   9,621,551  47.18 %
# 3        4                        Pune  Maharashtra   9,429,408  30.37 %
# 4        5             Mumbai Suburban  Maharashtra   9,356,962   8.29 %
# 5        6  South Twenty Four Parganas  West Bengal   8,161,961  18.17 %
#
#    Sex-Ratio  Literacy
# 0        886     84.53
# 1        955     84.06
# 2        916     87.67
# 3        915     86.15
# 4        860     89.91
# 5        956     77.51

# %%
literacy_of_district=df.groupby('District')['Literacy'].max().sort_values(ascending=False).head(6)

# %%
literacy_of_district_df=literacy_of_district.reset_index()
fig=px.bar(literacy_of_district_df,x='District',y='Literacy',color_discrete_sequence=['purple'], text='Literacy')
fig.update_layout(title_x=0.5)
fig.update_layout(title_text="Literacy rate of District of india in 2011")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Serchhip(Mizoram) district had the highest literacy rate = **97.91%**

# %% [markdown]
# #Q3. Which state had the highest sex-ratio in 2011?

# %%
df.head(6)
# Out:
#    Ranking                    District        State  Population   Growth  \
# 0        1                       Thane  Maharashtra  11,060,148  36.01 %
# 1        2  North Twenty Four Parganas  West Bengal  10,009,781  12.04 %
# 2        3                   Bangalore    Karnataka   9,621,551  47.18 %
# 3        4                        Pune  Maharashtra   9,429,408  30.37 %
# 4        5             Mumbai Suburban  Maharashtra   9,356,962   8.29 %
# 5        6  South Twenty Four Parganas  West Bengal   8,161,961  18.17 %
#
#    Sex-Ratio  Literacy
# 0        886     84.53
# 1        955     84.06
# 2        916     87.67
# 3        915     86.15
# 4        860     89.91
# 5        956     77.51

# %%
sex_ratio=df.groupby('State')['Sex-Ratio'].max().sort_values(ascending=False).head(6)

# %%
sex_ratio_df=sex_ratio.reset_index()
fig=px.bar(sex_ratio_df,x='State',y='Sex-Ratio',color_discrete_sequence=['blue'], text='Sex-Ratio')
fig.update_layout(title_x=0.5)
fig.update_layout(title_text='Sex ratio of states in india in 2011')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Puducherry had the highest sex-ratio in 2011 = **1184 females per 1000 males**

# %% [markdown]
# #Q4. Which district had the highest sex-ratio in 2011?

# %%
df.head(6)
# Out:
#    Ranking                    District        State  Population   Growth  \
# 0        1                       Thane  Maharashtra  11,060,148  36.01 %
# 1        2  North Twenty Four Parganas  West Bengal  10,009,781  12.04 %
# 2        3                   Bangalore    Karnataka   9,621,551  47.18 %
# 3        4                        Pune  Maharashtra   9,429,408  30.37 %
# 4        5             Mumbai Suburban  Maharashtra   9,356,962   8.29 %
# 5        6  South Twenty Four Parganas  West Bengal   8,161,961  18.17 %
#
#    Sex-Ratio  Literacy
# 0        886     84.53
# 1        955     84.06
# 2        916     87.67
# 3        915     86.15
# 4        860     89.91
# 5        956     77.51

# %%
district_sex_ratio=df.groupby(['State','District'])['Sex-Ratio'].max().sort_values(ascending=False).head(6)

# %%
district_sex_ratio_df=district_sex_ratio.reset_index()
fig=px.bar(district_sex_ratio_df,x='District',y='Sex-Ratio',color_discrete_sequence=['purple'],text='Sex-Ratio')
fig.update_layout(title_x=0.5)
fig.update_layout(title_text='Sex ratio of District in india in 2011')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Mahe(puducherry) district had the higest sex-ratio in 2011 = **1184 females per 1000 males**

# %%
df.head(6)
# Out:
#    Ranking                    District        State  Population   Growth  \
# 0        1                       Thane  Maharashtra  11,060,148  36.01 %
# 1        2  North Twenty Four Parganas  West Bengal  10,009,781  12.04 %
# 2        3                   Bangalore    Karnataka   9,621,551  47.18 %
# 3        4                        Pune  Maharashtra   9,429,408  30.37 %
# 4        5             Mumbai Suburban  Maharashtra   9,356,962   8.29 %
# 5        6  South Twenty Four Parganas  West Bengal   8,161,961  18.17 %
#
#    Sex-Ratio  Literacy
# 0        886     84.53
# 1        955     84.06
# 2        916     87.67
# 3        915     86.15
# 4        860     89.91
# 5        956     77.51

# %%
growth_rate=df.groupby('State')['Growth'].max().sort_values(ascending=False).head(6)
print(growth_rate)
# Out:
# State
# Nagaland          98.81 %
# Uttar Pradesh      9.92 %
# Assam              9.61 %
# Karnataka          9.54 %
# Andhra Pradesh     9.47 %
# West Bengal        9.46 %
# Name: Growth, dtype: object

# %% [markdown]
# #**Conclusion:**
# #The Census of India represents a vital dataset that offers in-depth insights into the demographics, social structure, and economic conditions of the nation. By analyzing this comprehensive information, we can uncover numerous details about the diverse population of India, including patterns of migration, education levels, and employment trends, which are essential for informed policymaking and development planning.
#
#
# ---
#
#
# #**Some of the key findings from this dataset are as follows:**
# #1.Mizoram had the highest litracy rate in 2011 = **97.91%**
# #2.Serchhip(Mizoram) district had the highest literacy rate = **97.91%**
# #3.Puducherry had the highest sex-ratio in 2011 = **1184 females per 1000 males**
# #4.Mahe(puducherry) district had the higest sex-ratio in 2011 = **1184 females per 1000 males**
#
#
# ---
#
# #**THANKYOU**
